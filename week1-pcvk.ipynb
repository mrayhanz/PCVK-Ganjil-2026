# %% [markdown]
# <a href="https://colab.research.google.com/github/mrayhanz/PCVK-Ganjil-2026/blob/main/week1-pcvk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://external-preview.redd.it/hJNL3HXwmJXzzIdyUKdsVQerrBIe0KbO7d26zEXWidE.jpg?auto=webp&s=4a8bf4911d40dddb64ebc30505e704003297f414"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)                                  #read image
    image = cv.resize(image, (0,0), fx=0.5, fy=0.5)         #resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)          #convert color to RGB
    final_frame = cv.hconcat((image, image_2))              #show image
    cv2_imshow(final_frame)                                 #show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
# Out:
# resolusi image: tinggi x lebar =  250  x  358

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=716x250>

# %% [markdown]
# **PERTANYAAN**
#
# 1	Mengapa menggunakan Google Colab?
#
# Karena Google Colab bisa menjalankan Python langsung melalui browser tanpa instalasi, serta mendukung library pengolahan citra seperti OpenCV dan NumPy.
#
# 2	Kegunaan library dan apakah semuanya wajib?
#
# •	NumPy > mengolah array/pixel.
#
# •	Pandas > mengolah data tabel.
#
# •	OpenCV > pengolahan citra.
#
# •	Skimage > pemrosesan citra.
#
# •	PIL > membaca/manipulasi gambar.
#
# •	Matplotlib > menampilkan gambar/grafik.
#
# Tidak semuanya wajib digunakan, tergantung kebutuhan praktikum.
#
# 3	Kegunaan cv.resize()?
#
# Untuk mengecilkan gambar menjadi 50% dari ukuran awal. Jika tidak digunakan, gambar tetap berukuran asli
#
# 4	Kegunaan [255,255,255]?
#
# Menunjukkan warna putih pada RGB
#
# 5	Hubungan pixel dan resolusi?
#
# Pixel adalah elemen terkecil gambar. Semakin tinggi resolusi, semakin banyak pixel sehingga gambar semakin detail.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for y in range(tinggi):
    image_3[y, int(lebar/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat 2 garis diagonal menyilang
for y in range(tinggi):
    x1 = int(y * lebar / tinggi)
    x2 = lebar - 1 - x1

    image_3[y, x1] = [255,255,255]
    image_3[y, x2] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal ditengah image dengan panjang tertentu
y = int(tinggi / 2)

for x in range(100, 200):
    image_3[y, x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=716x250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat kotak putih pada image
for y in range(100, 200):
    for x in range(100, 200):
        image_3[y, x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=716x250>
